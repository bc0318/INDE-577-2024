# %% [markdown]
# **Application on the Moon-shaped dataset. It is composed of two groups of data, each shaped like a semi-circle.**

# %% [markdown]
# Load necessary packages

# %%
from sklearn.datasets import make_moons
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# %% [markdown]
# Load the data

# %%
X, y = make_moons(n_samples=300, noise=0.1, random_state=1)

# %% [markdown]
# Apply DBSCAN

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

dbscan = DBSCAN(eps=0.3, min_samples=5)
clusters = dbscan.fit_predict(X_scaled)

# %% [markdown]
# Visualize the results

# %%
plt.scatter(X_scaled[:, 0], X_scaled[:, 1], c=clusters, cmap='viridis', marker='o', edgecolor='k', s=50)
plt.title('DBSCAN Clustering of Moon-shaped Data')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.colorbar()
plt.show()

# %% [markdown]
# <span style="color: blue;">DBSCAN performs well in classifying the dataset.</span>

# %% [markdown]
# ---
#
# ### Conclusion
#
# In summary, we find that DBSCAN is good at classifying in the Moon-shaped data task.
